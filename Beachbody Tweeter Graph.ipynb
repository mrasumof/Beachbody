# %%
from pymongo import MongoClient
from requests_oauthlib import OAuth1

client = MongoClient("52.25.140.201",27017)

db = client['Beachbody']
coll_tweets = db['tweets']

# %%
hashtag_raw_list = []
user_raw_list =[]

for each in coll_tweets.find({}):
    for each2 in each['hashtags']:
        hashtag_raw_list.append(each2)
        
    for each2 in each['tweeter_list']:
        user_raw_list.append(each2)

# %%
print len(hashtag_raw_list)
# Out:
# 1595

# %%
print len(user_raw_list)
# Out:
# 1818

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.DataFrame(hashtag_raw_list)

df.columns = ['Tag']

df2 = df.copy(deep=True)

x = df2['Tag'].value_counts()

# %%
x[0:24]
type(x)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10));
plt.hist(x[0:24],);
plt.title('Histogram of Hashtags by Count');
plt.show()

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(8,8))
data = x[0:24]
data.plot(kind="barh")

plt.figure(figsize=(8,8))
data2 = x[0:5]
data2.plot(kind="barh", color="r")

# %%
print data
# Out:
# #BOD                      296
# #workout                  115
# #fitness                   77
# #Samo                      51
# #health                    42
# #bod…                      40
# #Saturday!                 31
# #workout,                  30
# #gym                       26
# #TransformationTuesday     24
# #recipe                    21
# #gymlife                   20
# #gymfreak                  17
# #gymrat                    17
# #gymtime                   17
# #toptags                   17
# #21dayfix                  17
# #LoseWeight                16
# #weekend                   16
# #brunch                    15
# #bod                       13
# #P90Lunch                  13
# #ThirstyThursday           13
# #CDJ!                      12
# dtype: int64

# %%
plt.figure(figsize=(8,8))
data = x[0:24]

data.plot(kind="barh")

width = 0.5

count = 0
for rect in data:
#    xloc = width + 1   # Shift the text to the right side of the right edge
    xloc = 5
    clr = 'black'      # Black against white background
    align = 'left'

    # Center the text vertically in the bar
#    yloc = count
    yloc = 5
    print data[count]
    ax1.text(xloc, yloc, data[count], horizontalalignment=align,
             verticalalignment='center', color=clr, weight='bold')
    count += 1
# Out:
# 296
# 115
# 77
# 51
# 42
# 40
# 31
# 30
# 26
# 24
# 21
# 20
# 17
# 17
# 17
# 17
# 17
# 16
# 16
# 15
# 13
# 13
# 13
# 12

# %%
plt.subplots(figsize=(18,15))
data2 = x[0:24]
data3 = data2[::-1]

data3.plot(kind="barh")
plt.title('Top 25 Hashtags by Count');
ax.set_ylabel('Hashtag');
plt.xlabel('# of Times')

# %%
for each in data3:
    print each['Tag']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-714bff400326> in <module>()
#       1 for each in data3:
# ----> 2     print each['Tag']
#
# IndexError: invalid index to scalar variable.

# %%
#!/usr/bin/env python2
"""
Minimal Example
===============
Generating a square wordcloud from the US constitution using default arguments.
"""

from os import path
from wordcloud import WordCloud
import pickle

# Read the whole text.
hashtag = pickle.load(open("/Users/martinrasumoff/Desktop/JobSearch/hashtags","rb"))

text = ""
for each in hashtag:
    text = text + each + ","

#print text
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")

# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
#image = wordcloud.to_image()
#image.show()

# %%
#!/usr/bin/env python2
"""
Minimal Example
===============
Generating a square wordcloud from the US constitution using default arguments.
"""

from os import path
from wordcloud import WordCloud
import pickle

# Read the whole text.
hashtag = pickle.load(open("/Users/martinrasumoff/Desktop/JobSearch/fb_hashtags","rb"))

text = ""
for each in hashtag:
    text = text + each + ","

#print text
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")

# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
#image = wordcloud.to_image()
#image.show()

# %%
#!/usr/bin/env python2
"""
Minimal Example
===============
Generating a square wordcloud from the US constitution using default arguments.
"""

from os import path
from wordcloud import WordCloud
import pickle

# Read the whole text.
hashtag = pickle.load(open("/Users/martinrasumoff/Desktop/JobSearch/fb_hashtags","rb"))

text = ""
for each in hashtag:
    text = text + each + ","

#print text
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")

# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
#image = wordcloud.to_image()
#image.show()
